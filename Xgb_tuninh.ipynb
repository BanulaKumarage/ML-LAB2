# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, mean_squared_log_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from catboost import CatBoostRegressor
import seaborn as sns
from scipy.stats import uniform, randint

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.drop(['id'], axis=1, inplace=True)

# %%
X_train = train.drop(['cost', 'prepared_food'], axis=1)
y_train = train[['cost']]
X_test = test.drop(['id', 'prepared_food'], axis=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
import xgboost as xgb

xgb_regressor = xgb.XGBRegressor()

param_grid = {
    'n_estimators': range(100, 1001, 100),  # Number of boosting rounds
    'learning_rate': [0.01, 0.1, 0.2, 0.3, 0.5],  # Step size shrinkage
    'max_depth': range(3, 11),  # Maximum depth of a tree
    'min_child_weight': range(1, 6),  # Minimum sum of instance weight (hessian) needed in a child
    'gamma': [0, 0.1, 0.2, 0.3, 0.4],  # Minimum loss reduction required to make a further partition on a leaf node
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],  # Fraction of samples used for fitting the trees
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],  # Fraction of features used for fitting the trees
}

# Create the Randomized Search object
random_search = RandomizedSearchCV(
    xgb_regressor,
    param_distributions=param_grid,
    n_iter=100,  # Number of random combinations to try
    scoring='neg_mean_squared_error',  # Use mean squared error as the evaluation metric
    cv=5,  # Cross-validation folds
    verbose=2,  # Increase for more output
    n_jobs=-1  # Use all available CPU cores
)

# Fit the Randomized Search to your data
random_search.fit(X_train_scaled, y_train)

# Print the best hyperparameters and corresponding score
print("Best hyperparameters found:")
print(random_search.best_params_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  10.2s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  10.6s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  11.3s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  11.8s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  14.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  14.3s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  14.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  14.5s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.7; total time=  30.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.7; total time=  30.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  30.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  30.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  31.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  32.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.7; total time=  33.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.7; total time=  33.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.7; total time=  34.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=400, subsample=1.0; total time=  34.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=700, subsample=0.7; total time=  30.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=700, subsample=0.7; total time=  31.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=700, subsample=0.7; total time=  30.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.8; total time=  33.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.8; total time=  32.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=900, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=700, subsample=0.7; total time=  31.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=900, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.8; total time=  35.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.8; total time=  36.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=5, n_estimators=600, subsample=0.7; total time=  42.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.8; total time=  35.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=5, n_estimators=600, subsample=0.7; total time=  41.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=700, subsample=0.7; total time=  31.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=900, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=5, n_estimators=600, subsample=0.7; total time=  43.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=900, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=5, n_estimators=600, subsample=0.7; total time=  43.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=900, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   5.3s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=5, n_estimators=600, subsample=0.7; total time=  46.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=1.0; total time=  11.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=1.0; total time=  11.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=1.0; total time=  11.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  16.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  16.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  17.7s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.9; total time=  25.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  17.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  15.8s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.9; total time=  26.3s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.9; total time=  26.9s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.9; total time=  27.3s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=300, subsample=0.9; total time=  28.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   6.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   6.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   7.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   7.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.1s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   8.1s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   8.8s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   9.8s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=  10.6s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=  10.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=800, subsample=0.9; total time=  53.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=800, subsample=0.9; total time=  53.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=800, subsample=0.9; total time=  55.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=800, subsample=0.9; total time=  56.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=9, min_child_weight=4, n_estimators=800, subsample=0.9; total time=  58.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  30.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  33.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  33.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  37.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  36.2s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  15.7s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  18.2s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  16.6s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  17.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  17.2s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=  19.2s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=  18.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=  17.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.6; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   3.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   3.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.6; total time= 1.2min
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=  18.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   4.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=  17.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  56.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   4.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  51.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  54.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  55.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  20.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  57.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   6.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   4.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  19.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  19.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   9.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   9.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   9.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7; total time=  11.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  21.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  24.0s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.5, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   7.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.5, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   6.6s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.5, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   6.5s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  12.4s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.9; total time=  15.0s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.9; total time=  15.8s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  14.5s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.5, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   8.5s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.9; total time=  16.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.5, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   7.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=800, subsample=1.0; total time=  14.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.9; total time=  20.1s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.9; total time=  19.8s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   9.4s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.9; total time=  10.4s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   7.7s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.9; total time=  10.9s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   8.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=300, subsample=1.0; total time=  11.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=300, subsample=1.0; total time=  11.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=300, subsample=1.0; total time=  13.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=300, subsample=1.0; total time=  13.7s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=7, min_child_weight=4, n_estimators=300, subsample=1.0; total time=  15.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  25.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  28.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  29.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  31.4s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  25.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=600, subsample=1.0; total time=  32.1s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  27.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  26.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  23.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  24.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  30.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  25.3s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  36.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  25.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=8, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  28.4s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  14.4s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  16.1s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  14.8s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  14.3s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  16.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=900, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  14.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  14.8s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=900, subsample=0.8; total time=  41.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=900, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=900, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=900, subsample=0.8; total time=  38.6s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=900, subsample=1.0; total time= 1.3min
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=900, subsample=0.8; total time=  40.0s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=900, subsample=0.8; total time=  39.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=900, subsample=0.8; total time=  41.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=900, subsample=1.0; total time= 1.4min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   5.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   4.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   4.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   5.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   4.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.9; total time=  18.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.9; total time=  18.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.9; total time=  22.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.9; total time=  24.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   8.0s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.9; total time=  25.7s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   8.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   8.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=9, min_child_weight=4, n_estimators=700, subsample=0.6; total time= 1.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=9, min_child_weight=4, n_estimators=700, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=9, min_child_weight=4, n_estimators=700, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=9, min_child_weight=4, n_estimators=700, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.5, max_depth=9, min_child_weight=4, n_estimators=700, subsample=0.6; total time= 1.1min
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=600, subsample=1.0; total time=  22.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=1000, subsample=0.7; total time=  38.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=1000, subsample=0.7; total time=  38.5s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  15.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=1000, subsample=0.7; total time=  36.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=1000, subsample=0.7; total time=  41.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=600, subsample=1.0; total time=  22.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=1000, subsample=0.7; total time=  41.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=600, subsample=1.0; total time=  28.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=600, subsample=1.0; total time=  25.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=600, subsample=1.0; total time=  26.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  18.5s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  17.6s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  17.0s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  17.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=700, subsample=0.6; total time=  17.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=700, subsample=0.6; total time=  19.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=700, subsample=0.6; total time=  20.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=2, n_estimators=800, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=700, subsample=0.6; total time=  21.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=700, subsample=0.6; total time=  19.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=2, n_estimators=800, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=600, subsample=0.7; total time=  12.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=2, n_estimators=800, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=2, n_estimators=800, subsample=0.9; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=  23.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=2, n_estimators=800, subsample=0.9; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=  21.8s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=  20.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=600, subsample=0.7; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=  22.3s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   7.6s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=600, subsample=0.7; total time=  15.7s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=  20.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=600, subsample=0.7; total time=  13.3s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   6.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=600, subsample=0.7; total time=  15.6s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   7.9s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   8.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.6; total time=  11.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.6; total time=  12.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.6; total time=  13.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.6; total time=  13.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.6; total time=  15.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6; total time=  17.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6; total time=  21.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6; total time=  19.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6; total time=  21.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6; total time=  20.7s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  20.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  21.6s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  22.3s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=700, subsample=0.8; total time=  20.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.5, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.6; total time=  20.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.5, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.6; total time=  18.9s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.5, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.6; total time=  17.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.5, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.6; total time=  20.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.5, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.6; total time=  16.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.9; total time=  13.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   2.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.9; total time=  13.5s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.9; total time=  14.7s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.9; total time=  16.0s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.9; total time=  15.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=0.8; total time=  14.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=0.8; total time=  15.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=0.8; total time=  15.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=5, n_estimators=200, subsample=0.8; total time=  14.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  25.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  24.7s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  26.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  27.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=800, subsample=0.6; total time=  26.7s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=1000, subsample=0.7; total time= 1.6min
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=1000, subsample=0.7; total time= 1.6min
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  52.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=1000, subsample=0.7; total time= 1.7min
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  55.6s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=1000, subsample=0.7; total time= 1.7min
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  53.7s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=1000, subsample=0.7; total time= 1.7min
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  54.7s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  53.6s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.5, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  22.3s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.5, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  22.7s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.5, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  25.2s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.5, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  23.5s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.5, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  23.6s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 2.0min
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  16.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  15.5s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=1.0; total time=  13.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  15.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  16.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  17.7s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=1.0; total time=  14.5s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=1.0; total time=  15.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=1.0; total time=  15.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=1.0; total time=  16.0s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  51.7s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  49.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  50.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  52.0s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  51.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  32.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  32.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  35.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  33.7s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7; total time=  36.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  46.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.6; total time=  12.5s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.6; total time=  15.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  49.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  51.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  52.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.6; total time=  12.9s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.6; total time=  14.1s
# ...
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  46.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  14.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  15.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  48.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  48.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  50.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  13.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  51.3s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.6; total time=  10.8s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.6; total time=  11.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.6; total time=  10.9s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.6; total time=  11.3s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.6; total time=  11.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=900, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  23.3s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  25.2s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  27.0s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  24.3s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  23.6s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=900, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=900, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=900, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   5.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   6.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=8, min_child_weight=2, n_estimators=900, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.5, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   6.7s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=4, n_estimators=700, subsample=0.6; total time=  34.3s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=4, n_estimators=700, subsample=0.6; total time=  33.6s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=900, subsample=0.8; total time=  19.6s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=4, n_estimators=700, subsample=0.6; total time=  37.0s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=4, n_estimators=700, subsample=0.6; total time=  34.3s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.5, max_depth=6, min_child_weight=4, n_estimators=700, subsample=0.6; total time=  36.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=900, subsample=0.8; total time=  19.9s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=900, subsample=0.8; total time=  21.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.6; total time=  28.8s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=900, subsample=0.8; total time=  24.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.6; total time=  28.4s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=900, subsample=0.8; total time=  26.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.6; total time=  29.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.6; total time=  30.6s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.6; total time=  32.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  12.8s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  13.6s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  10.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  13.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.5, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  14.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=1000, subsample=1.0; total time= 1.7min
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=1000, subsample=1.0; total time= 1.6min
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=1000, subsample=1.0; total time= 1.6min
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  27.0s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  26.1s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  26.8s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=1000, subsample=1.0; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  29.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=1000, subsample=1.0; total time= 1.7min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  28.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  31.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  34.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  32.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.5, max_depth=6, min_child_weight=3, n_estimators=700, subsample=0.7; total time=  35.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=900, subsample=0.7; total time=  32.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=900, subsample=0.7; total time=  33.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=900, subsample=0.7; total time=  33.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=900, subsample=0.7; total time=  39.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=900, subsample=0.7; total time=  36.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=900, subsample=0.9; total time=  53.4s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=900, subsample=0.9; total time=  53.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  31.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  32.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=900, subsample=0.9; total time=  53.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=900, subsample=0.9; total time=  51.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  34.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  31.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  31.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=900, subsample=0.9; total time=  54.7s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   8.7s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   9.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=2, n_estimators=600, subsample=0.8; total time=  59.3s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   8.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=2, n_estimators=600, subsample=0.8; total time=  54.6s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   8.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=2, n_estimators=600, subsample=0.8; total time=  56.9s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   8.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=2, n_estimators=600, subsample=0.8; total time=  58.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=2, n_estimators=600, subsample=0.8; total time=  58.9s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  24.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  27.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  29.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  26.8s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.7; total time=  19.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.7; total time=  19.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.7; total time=  20.9s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.7; total time=  19.5s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.7; total time=  22.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=900, subsample=0.9; total time= 1.6min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  16.6s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=900, subsample=0.9; total time= 1.5min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  14.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  21.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=900, subsample=0.9; total time= 1.5min
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=900, subsample=0.9; total time= 1.5min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  19.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0; total time=  19.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=900, subsample=0.9; total time= 1.6min
# Best hyperparameters found:
# {'subsample': 0.8, 'n_estimators': 600, 'min_child_weight': 2, 'max_depth': 9, 'learning_rate': 0.01, 'gamma': 0.1, 'colsample_bytree': 1.0}
